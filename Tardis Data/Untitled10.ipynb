# %%
import asyncio
import nest_asyncio
from Live_Data import BinanceFutures
nest_asyncio.apply()

# %%
l=[]
binance_futures = BinanceFutures("btcusdt")
asyncio.run(binance_futures.main())
# Out:
# [datetime.datetime(2023, 5, 18, 17, 38, 53, 1691), '26867.90', '0.850', '26868.00', '8.885', '26867.90', 496373.167]
# [datetime.datetime(2023, 5, 18, 17, 38, 53, 107804), '26867.90', '0.881', '26868.00', '8.818', '26867.90', 496373.167]
# [datetime.datetime(2023, 5, 18, 17, 38, 53, 179734), '26867.90', '1.626', '26868.00', '10.786', '26867.90', 496373.39200000005]
# [datetime.datetime(2023, 5, 18, 17, 38, 53, 200532), '26867.90', '1.741', '26868.00', '6.320', '26867.90', 496373.39200000005]
# [datetime.datetime(2023, 5, 18, 17, 38, 53, 289490), '26867.90', '1.803', '26868.00', '2.213', '26867.90', 496373.52400000003]
# [datetime.datetime(2023, 5, 18, 17, 38, 53, 299495), '26867.90', '1.857', '26868.00', '2.213', '26867.90', 496373.52400000003]
# [datetime.datetime(2023, 5, 18, 17, 38, 53, 310494), '26867.90', '1.857', '26868.00', '2.213', '26867.90', 496373.52400000003]
# ...

# %%
l
# Out:
# []
